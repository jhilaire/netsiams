# %%
import os, sys, time, resource, re, gc, shutil
import django
import pandas as pd
sys.path.append('/home/galm/software/django/tmv/BasicBrowser/')
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "BasicBrowser.settings")
django.setup()
from scoping.models import *

p = Project.objects.get(pk=27)
q = Query.objects.get(pk=2777)

# %%
dps = DocPar.objects.filter(
    tag__id=650
)

#for dp in dps:
    

fields_1 = [
    'id',
    'doc__title',
    'doc__authors',
    'doc__PY',
    'doc__id',
    'text',
    'docownership__user__username',
    'docownership__relevant',
]


df1 = pd.DataFrame.from_dict(list(
    dps.values(*fields_1)
))

df1['text'] = df1['text'].str.replace('\r','')

df1 = df1[fields_1]

df1.head()

df1.to_csv('data/paragraphs.csv')

# %%
fields_2 = [
    'id',
    'note__user__username',
    'note__text',
    'docstatement__text',
    'docstatement__id',
    'docstatement__technology__name'    
]

df2 = pd.DataFrame.from_dict(list(
    dps.values(*fields_2)
))

df2 = df2[fields_2]

df2.to_csv('data/notes_statements.csv')

df2.head()
# Out:
#       id note__user__username        note__text  \
# 0  50239                 None              None
# 1  50239                 None              None
# 2  50258                 None              None
# 3  50258                 None              None
# 4  50326                 hilj      abstract
#
#                                   docstatement__text  docstatement__id  \
# 0  These sensitivity cases (LimBio) are very rele...             151.0
# 1  These sensitivity cases (LimBio) are very rele...             151.0
# 2  Limiting the potential for global net-negative...             152.0
# 3  Limiting the potential for global net-negative...             152.0
# 4  The results also show the critical role ofBECC...             154.0
#
#   docstatement__technology__name
# 0                    H7_Lim_tech
# 1                   O1_Overshoot
# 2                    H7_Lim_tech
# 3                    D1_Dynamics
# 4                          H2_2C
